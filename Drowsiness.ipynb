# %% [markdown]
# <a href="https://colab.research.google.com/github/ntajxyooj/drowsiness/blob/main/Drowsiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import laberias ທີ່ຕ້ອງການນໍາໃຊ້

# %%
import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator

# %%
import matplotlib.pyplot as plt
#plt.style.use('dark_background')

# %% [markdown]
# # ສະແເດງປະເພດຂໍ້ມູນຮູບພາບ Dataset

# %%
import os
def plot_imgs(directory, top=10):
    all_item_dirs = os.listdir(directory)
    item_files = [os.path.join(directory, file) for file in all_item_dirs][:5]
    plt.figure(figsize=(20, 20))
  
    for i, img_path in enumerate(item_files):
        plt.subplot(10, 10, i+1)
    
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
data_path = '/content/drive/MyDrive/Drowsiness/data/train'

directories = ['/Closed', '/Open', '/no_yawn', '/yawn']

for j in directories:
    plot_imgs(data_path+j)

# %%
batch_size = 128
train_datagen = ImageDataGenerator(horizontal_flip = True, 
                                  rescale = 1./255, 
                                  zoom_range = 0.2, 
                                  validation_split = 0.1)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# #ເອີ້ນຊຸດຂໍ້ມູນທີ່ຈະຝຶກ ແລະ ກວດທົດສອບ ມາໃຊ້

# %%
train_data_path = '/content/drive/MyDrive/Drowsiness/data/train'
test_data_path = '/content/drive/MyDrive/Drowsiness/data/test'

train_set = train_datagen.flow_from_directory(train_data_path, target_size = (256,256),
                                              batch_size = batch_size, 
                                              color_mode = 'grayscale',
                                              class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(test_data_path, target_size = (256,256),
                                              batch_size = batch_size, 
                                              color_mode = 'grayscale',
                                              class_mode = 'categorical')
# Out:
# Found 3404 images belonging to 4 classes.
# Found 863 images belonging to 4 classes.

# %% [markdown]
# #ກໍານົດ Params ຂອງ Model CNN

# %%
classes = 4 
model = Sequential()
model.add(Conv2D(32, (3,3), padding = 'same', input_shape = (256,256,1), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Flatten())

model.add(Dense(64, activation = 'relu'))

model.add(Dense(classes, activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 64)                8388672
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 8,481,604
# Trainable params: 8,481,604
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #ຝຶກສອນ ແລະ ກວດສອບ ແມ່ແບບ (Train and validate Model)

# %%
model.compile(loss ='categorical_crossentropy',optimizer='adam', metrics = ['accuracy'])

# %%
model_path="/content/drive/MyDrive/Drowsiness/drowsiness.h5"

checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, 
                              save_best_only=True, mode='max')

callbacks_list = [checkpoint]

# %%
num_epochs = 10
training_steps=train_set.n//train_set.batch_size
validation_steps =test_set.n//test_set.batch_size

# %%
history = model.fit_generator(train_set, epochs=num_epochs, steps_per_epoch=training_steps,validation_data=test_set,
                    validation_steps=validation_steps, callbacks = callbacks_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
# 26/26 [==============================] - ETA: 0s - loss: 1.1014 - accuracy: 0.4991
# Epoch 00001: val_accuracy improved from -inf to 0.71615, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 1758s 68s/step - loss: 1.1014 - accuracy: 0.4991 - val_loss: 0.8662 - val_accuracy: 0.7161
# Epoch 2/10
# 26/26 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.7424
# Epoch 00002: val_accuracy improved from 0.71615 to 0.79427, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 606s 23s/step - loss: 0.5658 - accuracy: 0.7424 - val_loss: 0.4934 - val_accuracy: 0.7943
# Epoch 3/10
# 26/26 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8028
# Epoch 00003: val_accuracy improved from 0.79427 to 0.81641, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 601s 23s/step - loss: 0.4128 - accuracy: 0.8028 - val_loss: 0.4554 - val_accuracy: 0.8164
# Epoch 4/10
# 26/26 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8437
# Epoch 00004: val_accuracy improved from 0.81641 to 0.89062, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 611s 23s/step - loss: 0.3384 - accuracy: 0.8437 - val_loss: 0.2706 - val_accuracy: 0.8906
# Epoch 5/10
# 26/26 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8556
# Epoch 00005: val_accuracy did not improve from 0.89062
# 26/26 [==============================] - 601s 23s/step - loss: 0.3125 - accuracy: 0.8556 - val_loss: 0.3805 - val_accuracy: 0.8568
# Epoch 6/10
# 26/26 [==============================] - ETA: 0s - loss: 0.3172 - accuracy: 0.8501
# Epoch 00006: val_accuracy improved from 0.89062 to 0.89193, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 605s 23s/step - loss: 0.3172 - accuracy: 0.8501 - val_loss: 0.2467 - val_accuracy: 0.8919
# Epoch 7/10
# 26/26 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8718
# Epoch 00007: val_accuracy improved from 0.89193 to 0.89844, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 607s 23s/step - loss: 0.2805 - accuracy: 0.8718 - val_loss: 0.2557 - val_accuracy: 0.8984
# Epoch 8/10
# 26/26 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.8816
# Epoch 00008: val_accuracy improved from 0.89844 to 0.90365, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 605s 23s/step - loss: 0.2612 - accuracy: 0.8816 - val_loss: 0.2200 - val_accuracy: 0.9036
# Epoch 9/10
# 26/26 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.8831
# Epoch 00009: val_accuracy did not improve from 0.90365
# 26/26 [==============================] - 599s 23s/step - loss: 0.2416 - accuracy: 0.8831 - val_loss: 0.2499 - val_accuracy: 0.8932
# Epoch 10/10
# 26/26 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.8950
# Epoch 00010: val_accuracy improved from 0.90365 to 0.90625, saving model to /content/drive/MyDrive/Drowsiness/drowsiness.h5
# 26/26 [==============================] - 598s 23s/step - loss: 0.2359 - accuracy: 0.8950 - val_loss: 0.2536 - val_accuracy: 0.9062

# %% [markdown]
# #ສະແດງຜົນການຝຶກ ແລະ ທົດສອບ ອອກມາເປັນ Graphcs

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
